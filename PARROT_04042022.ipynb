# %% [markdown]
# <a href="https://colab.research.google.com/github/ramiromelo/Colab_Parrot/blob/main/PARROT_04042022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install git+https://github.com/PrithivirajDamodaran/Parrot.git
# Out:
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Parrot.git to /tmp/pip-req-build-c4sqjotx
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Parrot.git /tmp/pip-req-build-c4sqjotx
# ...
#      |████████████████████████████████| 3.8 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 36.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.0 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 33.1 MB/s
# ...
#   Created wheel for parrot: filename=parrot-1.0-py3-none-any.whl size=8695 sha256=4088ab9de4967bf1f8b38e348207f35cf6698f8340dbfb52ab411a595b40b271
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xjbq46fn/wheels/d8/27/d8/b757755a5b0b804c59714fdd8a4e2733c20802f638f17f7d96
# ...

# %%
#Import Libraries
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
#Reproducibility
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %%
#Load Model
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)
# Out:
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/476 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/736 [00:00<?, ?B/s]
# ...

# %%
phrases = ["The customers found it easy to access the books and guides through website", "testing now"]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  The customers found it easy to access the books and guides through website
# ----------------------------------------------------------------------------------------------------
# ('customers found it easy to access books and guides on the site', 29)
# ('customers found it easy to access books and guides through the website', 24)
# ('the customers found it easy to download the books and guides through the website', 24)
# ('customers found it easy to access the books and guides through the website', 20)
# ('the customers found it easy to access the books and guides on the website', 19)
# ('the customers found it easy to access the books and guides through the website', 16)
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  testing now
# ...
